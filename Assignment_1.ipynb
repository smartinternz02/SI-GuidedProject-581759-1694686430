# %%
import pandas as pd

# %%
import numpy as np

# %%
arr_random = np.random.randint(low = 2, high = 10, size=(4,4))
arr_random
# Out:
# array([[4, 2, 3, 3],
#        [4, 9, 6, 8],
#        [6, 3, 3, 4],
#        [5, 6, 4, 4]])

# %%
pd.DataFrame(arr_random, columns = ["Random value 1", "Random value 2", "Random value 3", "Random value 4"])
# Out:
#    Random value 1  Random value 2  Random value 3  Random value 4
# 0               4               2               3               3
# 1               4               9               6               8
# 2               6               3               3               4
# 3               5               6               4               4

# %%
df.describe(include='all')
# Out:
#                0          1          2          3
# count   4.000000   4.000000   4.000000   4.000000
# mean    7.000000   8.000000   9.000000  10.000000
# std     5.163978   5.163978   5.163978   5.163978
# min     1.000000   2.000000   3.000000   4.000000
# 25%     4.000000   5.000000   6.000000   7.000000
# 50%     7.000000   8.000000   9.000000  10.000000
# 75%    10.000000  11.000000  12.000000  13.000000
# max    13.000000  14.000000  15.000000  16.000000

# %%
df.isnull().any()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# dtype: bool

# %%
df.loc[:, 2:3]
# Out:
#     2   3
# 0   3   4
# 1   7   8
# 2  11  12
# 3  15  16

# %%
df.iloc[0:4, 2:4]
# Out:
#     2   3
# 0   3   4
# 1   7   8
# 2  11  12
# 3  15  16
